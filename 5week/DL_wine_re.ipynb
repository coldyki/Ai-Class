# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
df2 = df.drop('Wine', axis=1)
df2
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      14.23        1.71  2.43  15.6  127     2.80        3.06
# 1      13.20        1.78  2.14  11.2  100     2.65        2.76
# 2      13.16        2.36  2.67  18.6  101     2.80        3.24
# 3      14.37        1.95  2.50  16.8  113     3.85        3.49
# 4      13.24        2.59  2.87  21.0  118     2.80        2.69
# ..       ...         ...   ...   ...  ...      ...         ...
# 173    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 13 columns]

# %%
y = df2['Alcohol']
X = df2.drop('Alcohol', axis =1)

X
# Out:
#      Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  Nonflavanoid.phenols  \
# 0          1.71  2.43  15.6  127     2.80        3.06                  0.28
# 1          1.78  2.14  11.2  100     2.65        2.76                  0.26
# 2          2.36  2.67  18.6  101     2.80        3.24                  0.30
# 3          1.95  2.50  16.8  113     3.85        3.49                  0.24
# 4          2.59  2.87  21.0  118     2.80        2.69                  0.39
# ..          ...   ...   ...  ...      ...         ...                   ...
# 173        5.65  2.45  20.5   95     1.68        0.61                  0.52
# 174        3.91  2.48  23.0  102     1.80        0.75                  0.43
# 175        4.28  2.26  20.0  120     1.59        0.69                  0.43
# 176        2.59  2.37  20.0  120     1.65        0.68                  0.53
# 177        4.10  2.74  24.5   96     2.05        0.76                  0.56
#
#      Proanth  Color.int   Hue    OD  Proline
# 0       2.29       5.64  1.04  3.92     1065
# 1       1.28       4.38  1.05  3.40     1050
# 2       2.81       5.68  1.03  3.17     1185
# 3       2.18       7.80  0.86  3.45     1480
# 4       1.82       4.32  1.04  2.93      735
# ..       ...        ...   ...   ...      ...
# 173     1.06       7.70  0.64  1.74      740
# 174     1.41       7.30  0.70  1.56      750
# 175     1.35      10.20  0.59  1.56      835
# 176     1.46       9.30  0.60  1.62      840
# 177     1.35       9.20  0.61  1.60      560
#
# [178 rows x 12 columns]

# %%
from tensorflow.keras import layers, models

Y = pd.get_dummies(y).values
X = X.values

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1])   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="mse",   # one-hot이면 categorical_crossentropy
    metrics=["mse"]
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 2195.6814 - mse: 2195.6814 - val_loss: 520.9629 - val_mse: 520.9629
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1146.8242 - mse: 1146.8242 - val_loss: 220.8891 - val_mse: 220.8891
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 734.5818 - mse: 734.5818 - val_loss: 109.1106 - val_mse: 109.1106
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 505.5097 - mse: 505.5097 - val_loss: 57.0256 - val_mse: 57.0256
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 358.9096 - mse: 358.9096 - val_loss: 34.7469 - val_mse: 34.7469
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 294.3734 - mse: 294.3734 - val_loss: 21.9694 - val_mse: 21.9694
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 208.5371 - mse: 208.5371 - val_loss: 9.5236 - val_mse: 9.5236
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 169.5926 - mse: 169.5926 - val_loss: 4.3233 - val_mse: 4.3233
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 146.3357 - mse: 146.3357 - val_loss: 1.5976 - val_mse: 1.5976
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 117.7324 - mse: 117.7324 - val_loss: 0.3063 - val_mse: 0.3063
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 95.9346 - mse: 95.9346 - val_loss: 0.0379 - val_mse: 0.0379
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 88.5681 - mse: 88.5681 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 81.4141 - mse: 81.4141 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 60.3960 - mse: 60.3960 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 59.9384 - mse: 59.9384 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 52.9429 - mse: 52.9429 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 37.5103 - mse: 37.5103 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 32.0433 - mse: 32.0433 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 26.1285 - mse: 26.1285 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 19.5227 - mse: 19.5227 - val_loss: 0.0091 - val_mse: 0.0091
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 30.6271 - mse: 30.6271 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.3912 - mse: 23.3912 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.5821 - mse: 14.5821 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 18.7596 - mse: 18.7596 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.7681 - mse: 14.7681 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.8565 - mse: 10.8565 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 10.6384 - mse: 10.6384 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 12.7527 - mse: 12.7527 - val_loss: 0.0092 - val_mse: 0.0092
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 10.3637 - mse: 10.3637 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 11.5922 - mse: 11.5922 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3793 - mse: 6.3793 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3915 - mse: 8.3915 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.8648 - mse: 8.8648 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1206 - mse: 7.1206 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.1847 - mse: 8.1847 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.9979 - mse: 9.9979 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2455 - mse: 7.2455 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3734 - mse: 4.3734 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5776 - mse: 5.5776 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1573 - mse: 4.1573 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4535 - mse: 6.4535 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7372 - mse: 6.7372 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5011 - mse: 5.5011 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6545 - mse: 4.6545 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.5034 - mse: 2.5034 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.0828 - mse: 6.0828 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8434 - mse: 4.8434 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7370 - mse: 1.7370 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4004 - mse: 3.4004 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4810 - mse: 2.4810 - val_loss: 0.0093 - val_mse: 0.0093

# %%
N_EPOCHS = 50
y_pred = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0092 - mse: 0.0092
# [0.009219333529472351, 0.009219333529472351]

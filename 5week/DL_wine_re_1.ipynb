# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine.csv")
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
df2 = df.drop('Wine', axis=1)
df2
# Out:
#      Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0      14.23        1.71  2.43  15.6  127     2.80        3.06
# 1      13.20        1.78  2.14  11.2  100     2.65        2.76
# 2      13.16        2.36  2.67  18.6  101     2.80        3.24
# 3      14.37        1.95  2.50  16.8  113     3.85        3.49
# 4      13.24        2.59  2.87  21.0  118     2.80        2.69
# ..       ...         ...   ...   ...  ...      ...         ...
# 173    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 13 columns]

# %%
y = df2['Alcohol']
X = df2.drop('Alcohol', axis =1)

X
# Out:
#      Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  Nonflavanoid.phenols  \
# 0          1.71  2.43  15.6  127     2.80        3.06                  0.28
# 1          1.78  2.14  11.2  100     2.65        2.76                  0.26
# 2          2.36  2.67  18.6  101     2.80        3.24                  0.30
# 3          1.95  2.50  16.8  113     3.85        3.49                  0.24
# 4          2.59  2.87  21.0  118     2.80        2.69                  0.39
# ..          ...   ...   ...  ...      ...         ...                   ...
# 173        5.65  2.45  20.5   95     1.68        0.61                  0.52
# 174        3.91  2.48  23.0  102     1.80        0.75                  0.43
# 175        4.28  2.26  20.0  120     1.59        0.69                  0.43
# 176        2.59  2.37  20.0  120     1.65        0.68                  0.53
# 177        4.10  2.74  24.5   96     2.05        0.76                  0.56
#
#      Proanth  Color.int   Hue    OD  Proline
# 0       2.29       5.64  1.04  3.92     1065
# 1       1.28       4.38  1.05  3.40     1050
# 2       2.81       5.68  1.03  3.17     1185
# 3       2.18       7.80  0.86  3.45     1480
# 4       1.82       4.32  1.04  2.93      735
# ..       ...        ...   ...   ...      ...
# 173     1.06       7.70  0.64  1.74      740
# 174     1.41       7.30  0.70  1.56      750
# 175     1.35      10.20  0.59  1.56      835
# 176     1.46       9.30  0.60  1.62      840
# 177     1.35       9.20  0.61  1.60      560
#
# [178 rows x 12 columns]

# %%
from tensorflow.keras import layers, models
Y=y.values
X = X.values

# %%
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(1)   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="mse",   # one-hot이면 categorical_crossentropy
    metrics=["mse"]
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 16552.7109 - mse: 16552.7109 - val_loss: 982.9308 - val_mse: 982.9308
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5119.2983 - mse: 5119.2983 - val_loss: 359.7825 - val_mse: 359.7825
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2474.1665 - mse: 2474.1665 - val_loss: 1419.0660 - val_mse: 1419.0660
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2252.5076 - mse: 2252.5076 - val_loss: 899.7112 - val_mse: 899.7112
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1765.4845 - mse: 1765.4845 - val_loss: 240.4275 - val_mse: 240.4275
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1104.8446 - mse: 1104.8446 - val_loss: 30.8353 - val_mse: 30.8353
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1817.2299 - mse: 1817.2299 - val_loss: 59.2224 - val_mse: 59.2224
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1208.1664 - mse: 1208.1664 - val_loss: 75.2931 - val_mse: 75.2931
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1211.8918 - mse: 1211.8918 - val_loss: 259.1491 - val_mse: 259.1491
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 982.9736 - mse: 982.9736 - val_loss: 277.2445 - val_mse: 277.2445
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 975.8892 - mse: 975.8892 - val_loss: 72.6444 - val_mse: 72.6444
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 920.0428 - mse: 920.0428 - val_loss: 37.4028 - val_mse: 37.4028
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1012.6504 - mse: 1012.6504 - val_loss: 96.5121 - val_mse: 96.5121
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 717.3813 - mse: 717.3813 - val_loss: 90.3583 - val_mse: 90.3583
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 582.6892 - mse: 582.6892 - val_loss: 116.1516 - val_mse: 116.1516
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 632.6152 - mse: 632.6152 - val_loss: 89.9689 - val_mse: 89.9689
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 464.6286 - mse: 464.6286 - val_loss: 67.6273 - val_mse: 67.6273
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 487.6721 - mse: 487.6721 - val_loss: 165.8524 - val_mse: 165.8524
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 538.3854 - mse: 538.3854 - val_loss: 330.9608 - val_mse: 330.9608
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 569.8287 - mse: 569.8287 - val_loss: 113.2411 - val_mse: 113.2411
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 463.8547 - mse: 463.8547 - val_loss: 50.3979 - val_mse: 50.3979
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 655.9248 - mse: 655.9248 - val_loss: 242.6205 - val_mse: 242.6205
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 479.5849 - mse: 479.5849 - val_loss: 458.3646 - val_mse: 458.3646
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 582.7643 - mse: 582.7643 - val_loss: 261.5988 - val_mse: 261.5988
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 480.3016 - mse: 480.3016 - val_loss: 33.6720 - val_mse: 33.6720
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 437.3569 - mse: 437.3569 - val_loss: 17.2317 - val_mse: 17.2317
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 455.9367 - mse: 455.9367 - val_loss: 60.0536 - val_mse: 60.0536
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 371.1032 - mse: 371.1032 - val_loss: 171.2386 - val_mse: 171.2386
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 397.4599 - mse: 397.4599 - val_loss: 48.8186 - val_mse: 48.8186
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 423.4449 - mse: 423.4449 - val_loss: 11.7904 - val_mse: 11.7904
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 249.5882 - mse: 249.5882 - val_loss: 48.4711 - val_mse: 48.4711
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 239.8564 - mse: 239.8564 - val_loss: 86.0841 - val_mse: 86.0841
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 257.3676 - mse: 257.3676 - val_loss: 37.7254 - val_mse: 37.7254
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 207.3657 - mse: 207.3657 - val_loss: 6.3710 - val_mse: 6.3710
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 333.0124 - mse: 333.0124 - val_loss: 79.6587 - val_mse: 79.6587
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 364.9091 - mse: 364.9091 - val_loss: 104.1839 - val_mse: 104.1839
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 246.7119 - mse: 246.7119 - val_loss: 5.1969 - val_mse: 5.1969
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 269.4630 - mse: 269.4630 - val_loss: 69.6380 - val_mse: 69.6380
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 266.0234 - mse: 266.0234 - val_loss: 92.1255 - val_mse: 92.1255
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 330.6642 - mse: 330.6642 - val_loss: 38.6314 - val_mse: 38.6314
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 230.3263 - mse: 230.3263 - val_loss: 14.1429 - val_mse: 14.1429
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 179.8415 - mse: 179.8415 - val_loss: 14.3856 - val_mse: 14.3856
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 339.2237 - mse: 339.2237 - val_loss: 39.5847 - val_mse: 39.5847
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 173.5951 - mse: 173.5951 - val_loss: 7.0442 - val_mse: 7.0442
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 204.1958 - mse: 204.1958 - val_loss: 15.7592 - val_mse: 15.7592
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 326.8804 - mse: 326.8804 - val_loss: 175.2001 - val_mse: 175.2001
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 287.4661 - mse: 287.4661 - val_loss: 5.0238 - val_mse: 5.0238
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 166.8214 - mse: 166.8214 - val_loss: 9.3749 - val_mse: 9.3749
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 190.4566 - mse: 190.4566 - val_loss: 2.9752 - val_mse: 2.9752
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 192.4829 - mse: 192.4829 - val_loss: 16.1061 - val_mse: 16.1061

# %%
N_EPOCHS = 50
y_pred = model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 16.6796 - mse: 16.6796
# [16.67961883544922, 16.67961883544922]

# %% [markdown]
# 202235275 심찬기

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

imdb = keras.datasets.imdb
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
np.unique(y_train,return_counts=True)
# Out:
# (array([0, 1]), array([12500, 12500]))

# %%
word_to_index = imdb.get_word_index()

word_to_index = {k:(v+3) for k,v in word_to_index.items()}
word_to_index["<PAD>"] = 0
word_to_index["<START>"] = 1
word_to_index["<UNK>"] = 2
word_to_index["<UNUSED>"] = 3

index_to_word = dict([value,key] for (key,value) in word_to_index.items())

print(' '.join([index_to_word[index] for index in x_train[0]]))
# Out:
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import *

x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %%
vocab_size = 10000

model = Sequential()
model.add(Embedding(vocab_size, 64 , input_length=100))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=64,epochs=20, verbose=1 ,validation_data=(x_test,y_test))
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 12s 29ms/step - accuracy: 0.7790 - loss: 0.4457 - val_accuracy: 0.8484 - val_loss: 0.3421
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9530 - loss: 0.1325 - val_accuracy: 0.8284 - val_loss: 0.4581
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9968 - loss: 0.0155 - val_accuracy: 0.8286 - val_loss: 0.5765
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 16s 33ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.8355 - val_loss: 0.5962
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 1.0000 - loss: 5.5347e-04 - val_accuracy: 0.8367 - val_loss: 0.6224
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 1.0000 - loss: 3.2739e-04 - val_accuracy: 0.8376 - val_loss: 0.6450
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 1.0000 - loss: 1.8567e-04 - val_accuracy: 0.8377 - val_loss: 0.6636
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 1.0000 - loss: 1.2921e-04 - val_accuracy: 0.8382 - val_loss: 0.6800
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 1.0000 - loss: 9.3881e-05 - val_accuracy: 0.8377 - val_loss: 0.6966
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 1.0000 - loss: 6.9620e-05 - val_accuracy: 0.8386 - val_loss: 0.7111
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 1.0000 - loss: 5.2578e-05 - val_accuracy: 0.8384 - val_loss: 0.7260
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 1.0000 - loss: 4.0281e-05 - val_accuracy: 0.8383 - val_loss: 0.7404
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 29ms/step - accuracy: 1.0000 - loss: 3.1195e-05 - val_accuracy: 0.8388 - val_loss: 0.7536
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 13s 34ms/step - accuracy: 1.0000 - loss: 2.4197e-05 - val_accuracy: 0.8384 - val_loss: 0.7672
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 1.0000 - loss: 1.8995e-05 - val_accuracy: 0.8387 - val_loss: 0.7805
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 1.0000 - loss: 1.5068e-05 - val_accuracy: 0.8384 - val_loss: 0.7940
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 1.0000 - loss: 1.1783e-05 - val_accuracy: 0.8389 - val_loss: 0.8066
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 1.0000 - loss: 9.3593e-06 - val_accuracy: 0.8380 - val_loss: 0.8207
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 1.0000 - loss: 7.4641e-06 - val_accuracy: 0.8387 - val_loss: 0.8322
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 1.0000 - loss: 5.9522e-06 - val_accuracy: 0.8390 - val_loss: 0.8447

# %%
results = model.evaluate(x_test, y_test, verbose=2)
print(results)
# Out:
# 782/782 - 2s - 2ms/step - accuracy: 0.8390 - loss: 0.8447
# [0.8447182774543762, 0.8389999866485596]

# %%
review = "What can I say about this movie that was already said? It is my favorite time travel sci-fi, adventure epic comedy in the 80's and I love this movie to death! When I saw this movie I was thrown out by its theme. An excellent sci-fi, adventure epic, I LOVE the 80s. It's simple the greatest time travel movie ever happened in the history of world cinema. I love this movie to death, I love, LOVE, love it!"

# %%
import re

review = re.sub("[^0-9a-zA-Z]", " ", review).lower()

review_encoding = []

for w in review.split():
  index = word_to_index.get(w,2)
  if index <= 10000:
    review_encoding.append(index)
  else:
    review_encoding.append(word_to_index["<UNK>"])

test_input = pad_sequences([review_encoding], maxlen = 100)
value = model.predict(test_input)

if (value > 0.5):
  print("긍정적인 리뷰입니다")
else:
  print("부정적인 리뷰입니다")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 긍정적인 리뷰입니다

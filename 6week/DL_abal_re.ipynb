# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/abalone.csv", index_col=0)
df
# Out:
#      Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
le = LabelEncoder()
df['Sex'] =le.fit_transform(df['Sex'])

df
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# id
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera_weight  Shell_weight  Rings
# id
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
y = df['Rings']
X = df.drop('Rings', axis=1)

# %%
Y = pd.get_dummies(y).values
X = X.values

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model = models.Sequential([
    layers.Dense(64, activation="relu", input_shape=(X.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation="relu"),
    layers.Dense(Y.shape[1])   # 클래스 수 맞춤
])

model.compile(
    optimizer="adam",
    loss="mse",   # one-hot이면 categorical_crossentropy
    metrics=["mse"]
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 47.7176 - mse: 47.7176 - val_loss: 8.8344 - val_mse: 8.8344
# Epoch 2/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.6781 - mse: 8.6781 - val_loss: 7.5073 - val_mse: 7.5073
# Epoch 3/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.9160 - mse: 7.9160 - val_loss: 7.1218 - val_mse: 7.1218
# Epoch 4/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.4640 - mse: 7.4640 - val_loss: 6.8824 - val_mse: 6.8824
# Epoch 5/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.3784 - mse: 7.3784 - val_loss: 6.7364 - val_mse: 6.7364
# Epoch 6/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1437 - mse: 7.1437 - val_loss: 6.5234 - val_mse: 6.5234
# Epoch 7/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.2148 - mse: 7.2148 - val_loss: 6.3943 - val_mse: 6.3943
# Epoch 8/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.1853 - mse: 7.1853 - val_loss: 6.2541 - val_mse: 6.2541
# Epoch 9/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.8945 - mse: 6.8945 - val_loss: 6.1111 - val_mse: 6.1111
# Epoch 10/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.6037 - mse: 6.6037 - val_loss: 5.9775 - val_mse: 5.9775
# Epoch 11/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.4566 - mse: 6.4566 - val_loss: 5.7954 - val_mse: 5.7954
# Epoch 12/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.3629 - mse: 6.3629 - val_loss: 5.6433 - val_mse: 5.6433
# Epoch 13/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.1317 - mse: 6.1317 - val_loss: 5.5342 - val_mse: 5.5342
# Epoch 14/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0742 - mse: 6.0742 - val_loss: 5.5013 - val_mse: 5.5013
# Epoch 15/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 6.0493 - mse: 6.0493 - val_loss: 5.3552 - val_mse: 5.3552
# Epoch 16/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8698 - mse: 5.8698 - val_loss: 5.2376 - val_mse: 5.2376
# Epoch 17/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.8224 - mse: 5.8224 - val_loss: 5.1759 - val_mse: 5.1759
# Epoch 18/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.7084 - mse: 5.7084 - val_loss: 5.1567 - val_mse: 5.1567
# Epoch 19/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.5598 - mse: 5.5598 - val_loss: 5.0779 - val_mse: 5.0779
# Epoch 20/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.7934 - mse: 5.7934 - val_loss: 5.3016 - val_mse: 5.3016
# Epoch 21/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.5651 - mse: 5.5651 - val_loss: 5.0255 - val_mse: 5.0255
# Epoch 22/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.5294 - mse: 5.5294 - val_loss: 4.9951 - val_mse: 4.9951
# Epoch 23/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 5.5012 - mse: 5.5012 - val_loss: 4.9848 - val_mse: 4.9848
# Epoch 24/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.3403 - mse: 5.3403 - val_loss: 4.9882 - val_mse: 4.9882
# Epoch 25/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3275 - mse: 5.3275 - val_loss: 4.9283 - val_mse: 4.9283
# Epoch 26/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3696 - mse: 5.3696 - val_loss: 5.3713 - val_mse: 5.3713
# Epoch 27/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3143 - mse: 5.3143 - val_loss: 4.8936 - val_mse: 4.8936
# Epoch 28/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3839 - mse: 5.3839 - val_loss: 4.8906 - val_mse: 4.8906
# Epoch 29/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.2563 - mse: 5.2563 - val_loss: 4.8884 - val_mse: 4.8884
# Epoch 30/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.3438 - mse: 5.3438 - val_loss: 4.9723 - val_mse: 4.9723
# Epoch 31/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.1054 - mse: 5.1054 - val_loss: 5.1009 - val_mse: 5.1009
# Epoch 32/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.1448 - mse: 5.1448 - val_loss: 4.8826 - val_mse: 4.8826
# Epoch 33/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.0123 - mse: 5.0123 - val_loss: 5.0969 - val_mse: 5.0969
# Epoch 34/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.0183 - mse: 5.0183 - val_loss: 4.9849 - val_mse: 4.9849
# Epoch 35/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9640 - mse: 4.9640 - val_loss: 5.1795 - val_mse: 5.1795
# Epoch 36/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 5.0173 - mse: 5.0173 - val_loss: 4.9110 - val_mse: 4.9110
# Epoch 37/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8855 - mse: 4.8855 - val_loss: 5.2383 - val_mse: 5.2383
# Epoch 38/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9161 - mse: 4.9161 - val_loss: 5.0857 - val_mse: 5.0857
# Epoch 39/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8861 - mse: 4.8861 - val_loss: 5.0479 - val_mse: 5.0479
# Epoch 40/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8237 - mse: 4.8237 - val_loss: 5.1129 - val_mse: 5.1129
# Epoch 41/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9812 - mse: 4.9812 - val_loss: 4.9544 - val_mse: 4.9544
# Epoch 42/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.8865 - mse: 4.8865 - val_loss: 4.8743 - val_mse: 4.8743
# Epoch 43/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 4.9251 - mse: 4.9251 - val_loss: 5.0042 - val_mse: 5.0042
# Epoch 44/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 5.0031 - mse: 5.0031 - val_loss: 4.8807 - val_mse: 4.8807
# Epoch 45/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.8870 - mse: 4.8870 - val_loss: 4.9691 - val_mse: 4.9691
# Epoch 46/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 4.8857 - mse: 4.8857 - val_loss: 4.9968 - val_mse: 4.9968
# Epoch 47/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9559 - mse: 4.9559 - val_loss: 4.9368 - val_mse: 4.9368
# Epoch 48/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.8110 - mse: 4.8110 - val_loss: 5.0380 - val_mse: 5.0380
# Epoch 49/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9831 - mse: 4.9831 - val_loss: 4.9429 - val_mse: 4.9429
# Epoch 50/50
# 167/167 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4.9934 - mse: 4.9934 - val_loss: 5.3178 - val_mse: 5.3178

# %%
N_EPOCHS = 50
y_pred = model.predict(X_test)
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))
plt.plot(range(N_EPOCHS), history.history['loss'], label='train loss')
plt.plot(range(N_EPOCHS), history.history['val_loss'], label='test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
model.evaluate(X_test, y_test)
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3085 - mse: 5.3085
# [5.308534622192383, 5.308534622192383]
